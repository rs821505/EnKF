# %%
from Lorenz96 import L96
from EnsembleKF import EnKF

# %%
if __name__== "__main__":

    Forward_model = L96()
    Filter = EnKF(Forward_model,num_steps=500)
    Filter.Run_Ensemble()
    Filter.EnKF_Plot()
    Filter.Metrics()
# Out:
# Time Averaged RMSE:
#  1.812384721080181
#
# Minimum RMSE:
#  0.5777601215650637
#
# Time Averaged L2 Error:
#  11.46252743020471
#
# Minimum L2 Error:
#  3.6540758507227364
#
# Time Averaged Misfit:
#  14.046228118828726
#
# Minimum misfit:
#  7.441433278954326
